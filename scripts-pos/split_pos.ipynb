# %% [markdown]
# # split_pos
#
# Split positive data into training / validation / test.
#
# The distribution is 8:1:1.

# %% [markdown]
# ## Load data

# %%
import numpy as np
import random 
import pandas as pd

seed_val = 0
random.seed(seed_val)
np.random.seed(seed_val)

# %%
df = pd.read_csv('../csv_data/output-pos-remove_no_abst.csv', encoding='utf-8', header=None, dtype=str).fillna('')
df.columns = ['pmid','title','abstract','doi','year','authors']
df
# Out:
#          pmid                                              title  \
# 0    10028969  Frizzled regulation of Notch signalling polari...
# 1    10101114  Cis-regulatory elements of the mitotic regulat...
# 2    10198247  Identification of a novel cis-acting positive ...
# 3    10198632  twin of eyeless, a second Pax-6 gene of Drosop...
# 4    10207149  Direct regulatory interaction of the eyeless p...
# ..        ...                                                ...
# 894   9847251  Regulation of Pax6 expression is conserved bet...
# 895   9858707  Transcriptional control of Drosophila bicoid b...
# 896   9882489  Drosophila mef2 expression during mesoderm dev...
# 897   9892357  A LIM-homeodomain combinatorial code for motor...
# 898   9892673  Functional analysis of an eye specific enhance...
#
#                                               abstract  \
# 0    The Drosophila eye, a paradigm for epithelial ...
# 1    Mitosis in most Drosophila cells is triggered ...
# 2    The Drosophila NK-1 homeobox gene belongs to t...
# 3    The Drosophila Pax-6 gene eyeless (ey) plays a...
# 4    The Pax-6 gene encodes a transcription factor ...
# ..                                                 ...
# 894  Pax6 plays a key role in visual system develop...
# 895  Concentration of maternal BICOID (BCD) establi...
# 896  The function of the Drosophila mef2 gene, a me...
# 897  Different classes of vertebrate motor neuron t...
# 898  The development of the Drosophila compound eye...
#
#                                doi  year  \
# 0                    10.1038/17395  1999
# 1                                   1999
# 2           10.1006/bbrc.1999.0501  1999
# 3    10.1016/s1097-2765(00)80457-8  1999
# 4                                   1999
# ..                             ...   ...
# 894                                 1999
# 895  10.1016/s0925-4773(98)00159-2  1998
# 896         10.1006/dbio.1998.9081  1998
# 897                  10.1038/16275  1999
# 898          10.1073/pnas.96.2.564  1999
#
#                                                authors
# 0                                 M T Cooper, S J Bray
# 1    D A Lehman, B Patterson, L A Johnston, T Balze...
# 2                             S J Kim, T Park, K K Lee
# 3    T Czerny, G Halder, U Kloter, A Souabni, W J G...
# 4    T Niimi, M Seimiya, U Kloter, S Flister, W J G...
# ..                                                 ...
# 894  P X Xu, X Zhang, S Heaney, A Yoon, A M Michels...
# 895                         C Ruez, F Payre, A Vincent
# 896                                   H T Nguyen, X Xu
# 897     S Thor, S G Andersson, A Tomlinson, J B Thomas
# 898                   B Hauck, W J Gehring, U Walldorf
#
# [899 rows x 6 columns]

# %% [markdown]
# ## Shuffle
#
# Shuffle the dataframe by sample() method.

# %%
sh_df = df.sample(frac=1, random_state=0)
sh_df
# Out:
#          pmid                                              title  \
# 492  22115527  Erroneous attribution of relevant transcriptio...
# 141   1327756  Regulation of even-skipped stripe 2 in the Dro...
# 409  20213139  The winged-helix transcription factor JUMU reg...
# 31   10660673  Cardiac enhancer activity of the homeobox gene...
# 570   2478402  Dorsal expression of the Drosophila z600 gene ...
# ..        ...                                                ...
# 835   8660878  Disperse versus compact elements for the regul...
# 192  15479229  Expression of the Drosophila melanogaster ATP ...
# 629  26204530  Genome-Wide Mapping of Collier In Vivo Binding...
# 559  24496624  Machine learning classification of cell-specif...
# 684   2905685  Control elements of the P2 promoter of the Ant...
#
#                                               abstract  \
# 492  Background:\n\n\n\n\n      Cis-regulatory modu...
# 141  In an effort to determine how crude gradients ...
# 409  The PEV-modifying winged-helix/forkhead domain...
# 31   The Drosophila homeobox gene tinman plays a cr...
# 570  The Drosophila z600 gene is a member of an ove...
# ..                                                 ...
# 835  The segmented body pattern of the Drosophila e...
# 192  Mitochondrial biogenesis is a complex and high...
# 629  Collier, the single Drosophila COE (Collier/EB...
# 559  The Drosophila heart is composed of two distin...
# 684  Antennapedia (Antp), a homeotic gene of Drosop...
#
#                                   doi  year  \
# 492          10.1186/1471-2164-12-578  2011
# 141                                    1992
# 409         10.1007/s10577-010-9118-y  2010
# 31                                     2000
# 570      10.1016/0012-1606(89)90143-7  1989
# ..                                ...   ...
# 835            10.1006/dbio.1996.0146  1996
# 192  10.1111/j.1432-1033.2004.04336.x  2004
# 629      10.1371/journal.pone.0133387  2015
# 559                10.1242/dev.101709  2014
# 684            10.1101/gad.2.12a.1600  1988
#
#                                                authors
# 492  Marc S Halfon, Qianqian Zhu, Elizabeth R Brenn...
# 141                         S Small, A Blair, M Levine
# 409  Annemarie Hofmann, Madeleine Brünner, Alexande...
# 31   T V Venkatesh, M Park, K Ocorr, J Nemaceck, K ...
# 570                             R A Schulz, J L Miksch
# ..                                                 ...
# 835          M Klingler, J Soong, B Butler, J P Gergen
# 192  Ana Talamillo, Miguel Angel Fernández-Moreno, ...
# 629  Mathilde de Taffin, Yannick Carrier, Laurence ...
# 559  Shaad M Ahmad, Brian W Busser, Di Huang, Eliza...
# 684                              A M Boulet, M P Scott
#
# [899 rows x 6 columns]

# %% [markdown]
# ## Output

# %%
num_valid = round (len(sh_df) * 0.1)
num_test = round (len(sh_df) * 0.1)
num_train = len(sh_df) - num_valid - num_test
print('num_train:', num_train)
print('num_valid:', num_valid)
print('num_test:', num_test)
print()
print('check sum:', num_train + num_valid + num_test)
# Out:
# num_train: 719
# num_valid: 90
# num_test: 90
#
# check sum: 899

# %%
def rmv_blank(df:pd.DataFrame):
    """
    Remove redundant blank in abstract.
    
    Args:
        df(DataFrame)
    """
    for idx in range(len(df)):
        bef_abs = df.iloc[idx]['abstract']
        bef_abs_split = bef_abs.split()
        aft_abs = ' '.join(bef_abs_split)
        df.iloc[idx]['abstract'] = aft_abs

# %%
train_df = sh_df[:num_train]
rmv_blank(train_df)
train_df.to_csv('./csv_data/train.csv', index=False, encoding='utf-8')
train_df
# Out:
#          pmid                                              title  \
# 492  22115527  Erroneous attribution of relevant transcriptio...
# 141   1327756  Regulation of even-skipped stripe 2 in the Dro...
# 409  20213139  The winged-helix transcription factor JUMU reg...
# 31   10660673  Cardiac enhancer activity of the homeobox gene...
# 570   2478402  Dorsal expression of the Drosophila z600 gene ...
# ..        ...                                                ...
# 117  12537575  Assessing the impact of comparative genomic se...
# 464  21430782      A cis-regulatory map of the Drosophila genome
# 25   10619432  A pdf neuropeptide gene mutation and ablation ...
# 110  12421707  The Drosophila Pox neuro gene: control of male...
# 149   1373375  Insect immunity: developmental and inducible a...
#
#                                               abstract  \
# 492  Background: Cis-regulatory modules are bound b...
# 141  In an effort to determine how crude gradients ...
# 409  The PEV-modifying winged-helix/forkhead domain...
# 31   The Drosophila homeobox gene tinman plays a cr...
# 570  The Drosophila z600 gene is a member of an ove...
# ..                                                 ...
# 117  Background: It is widely accepted that compara...
# 464  Systematic annotation of gene regulatory eleme...
# 25   The mechanisms by which circadian pacemaker sy...
# 110  We have dissected the entire cis-regulatory re...
# 149  Diptericins are 9 kDa inducible antibacterial ...
#
#                                    doi  year  \
# 492           10.1186/1471-2164-12-578  2011
# 141                                     1992
# 409          10.1007/s10577-010-9118-y  2010
# 31                                      2000
# 570       10.1016/0012-1606(89)90143-7  1989
# ..                                 ...   ...
# 117  10.1186/gb-2002-3-12-research0086  2002
# 464                10.1038/nature09990  2011
# 25       10.1016/s0092-8674(00)81676-1  1999
# 110                  10.1242/dev.00157  2002
# 149                                     1992
#
#                                                authors
# 492  Marc S Halfon, Qianqian Zhu, Elizabeth R Brenn...
# 141                         S Small, A Blair, M Levine
# 409  Annemarie Hofmann, Madeleine Brünner, Alexande...
# 31   T V Venkatesh, M Park, K Ocorr, J Nemaceck, K ...
# 570                             R A Schulz, J L Miksch
# ..                                                 ...
# 117  Casey M Bergman, Barret D Pfeiffer, Diego E Ri...
# 464  Nicolas Nègre, Christopher D Brown, Lijia Ma, ...
# 25   S C Renn, J H Park, M Rosbash, J C Hall, P H T...
# 110                           Werner Boll, Markus Noll
# 149  J M Reichhart, M Meister, J L Dimarcq, D Zacha...
#
# [719 rows x 6 columns]

# %%
valid_df = sh_df[num_train:num_train+num_valid]
rmv_blank(valid_df)
valid_df.to_csv('./csv_data/valid.csv', index=False, encoding='utf-8')
valid_df
# Out:
#          pmid                                              title  \
# 152  14507783  Tgfbeta signaling acts on a Hox response eleme...
# 528   2328832  Cooperative enhancement at the Drosophila Sgs-...
# 696   2975615  Analysis of the promoter of the Rh2 opsin gene...
# 621  25835988  The evolutionary origination and diversificati...
# 461  21383317  High resolution mapping of Twist to DNA in Dro...
# ..        ...                                                ...
# 143   1356761  Sharp anterior boundary of homeotic gene expre...
# 180  15314643  Cellular immune response to parasitization in ...
# 131  12758126  Transcription control of a gene for Drosophila...
# 861   9250684  Mechanism and Bicoid-dependent control of hair...
# 47   10903170  The enhancer of split complex of Drosophila in...
#
#                                               abstract  \
# 152  Hox proteins play fundamental roles in generat...
# 528  The Drosophila glue gene Sgs-3 is specifically...
# 696  We have analyzed the cis-acting regulatory seq...
# 621  The origination and diversification of morphol...
# 461  Cis-regulatory modules (CRMs) function by bind...
# ..                                                 ...
# 143  Parasegmental boundaries in the Drosophila emb...
# 180  Drosophila immune response involves three type...
# 131  A DNA replication-related element (DRE)-bindin...
# 861  Pair-rule gene hairy (h) expression in seven e...
# 47   During Drosophila development, transcriptional...
#
#                                doi  year  \
# 152              10.1242/dev.00760  2003
# 528   10.1016/0012-1606(90)90283-o  1990
# 696                                 1988
# 621   10.1371/journal.pgen.1005136  2015
# 461          10.1101/gr.104018.109  2011
# ..                             ...   ...
# 143                                 1992
# 180   10.1371/journal.pbio.0020196  2004
# 131  10.1016/s0378-1119(03)00493-1  2003
# 861       10.1093/emboj/16.14.4403  1997
# 47                                  2000
#
#                                                authors
# 152  Aurélie Grienenberger, Samir Merabet, John Man...
# 528  M Roark, K V Raghavan, T Todo, C A Mayeda, E M...
# 696      D Mismer, W M Michael, T R Laverty, G M Rubin
# 621  Eric M Camino, John C Butts, Alison Ordway, Jo...
# 461  Anil Ozdemir, Katherine I Fisher-Aylor, Shirle...
# ..                                                 ...
# 143                                  J Müller, M Bienz
# 180  Michèle Crozatier, Jean-Michel Ubeda, Alain Vi...
# 131  Eunjeong Kwon, Hirokazu Seto, Fumiko Hirose, N...
# 861  A La Rosée, T Häder, H Taubert, R Rivera-Pomar...
# 47                     E C Lai, R Bodner, J W Posakony
#
# [90 rows x 6 columns]

# %%
test_df = sh_df[num_train+num_valid:num_train+2*num_valid]
rmv_blank(test_df)
test_df.to_csv('./csv_data/test.csv', index=False, encoding='utf-8')
test_df
# Out:
#          pmid                                              title  \
# 774   7821226  Regulation of a decapentaplegic midgut enhance...
# 324  18234213  dFOXO regulates transcription of a Drosophila ...
# 203  15737936  Genetic programs activated by proneural protei...
# 84   11752402  Regulatory DNA required for vnd/NK-2 homeobox ...
# 633  26369287  The fatty acid elongase Bond is essential for ...
# ..        ...                                                ...
# 835   8660878  Disperse versus compact elements for the regul...
# 192  15479229  Expression of the Drosophila melanogaster ATP ...
# 629  26204530  Genome-Wide Mapping of Collier In Vivo Binding...
# 559  24496624  Machine learning classification of cell-specif...
# 684   2905685  Control elements of the P2 promoter of the Ant...
#
#                                               abstract  \
# 774  The clustered homeotic genes encode transcript...
# 324  Insulin resistance is a major feature of patho...
# 203  Neurogenesis depends on a family of proneural ...
# 84   Vnd/NK-2 protein was detected in 11 neuroblast...
# 633  Insects use a spectacular variety of chemical ...
# ..                                                 ...
# 835  The segmented body pattern of the Drosophila e...
# 192  Mitochondrial biogenesis is a complex and high...
# 629  Collier, the single Drosophila COE (Collier/EB...
# 559  The Drosophila heart is composed of two distin...
# 684  Antennapedia (Antp), a homeotic gene of Drosop...
#
#                                   doi  year  \
# 774                                    1994
# 324         10.1016/j.jmb.2007.12.042  2008
# 203      10.1016/j.devcel.2005.01.020  2005
# 84             10.1073/pnas.012584599  2002
# 633                10.1038/ncomms9263  2015
# ..                                ...   ...
# 835            10.1006/dbio.1996.0146  1996
# 192  10.1111/j.1432-1033.2004.04336.x  2004
# 629      10.1371/journal.pone.0133387  2015
# 559                10.1242/dev.101709  2014
# 684            10.1101/gad.2.12a.1600  1988
#
#                                                authors
# 774                  J R Manak, L D Mathies, M P Scott
# 324                       Terhi Vihervaara, Oscar Puig
# 203                      Nick Reeves, James W Posakony
# 84   Xiaoping Shao, Keita Koizumi, Neil Nosworthy, ...
# 633  Wan Chin Ng, Jacqueline S R Chin, Kah Junn Tan...
# ..                                                 ...
# 835          M Klingler, J Soong, B Butler, J P Gergen
# 192  Ana Talamillo, Miguel Angel Fernández-Moreno, ...
# 629  Mathilde de Taffin, Yannick Carrier, Laurence ...
# 559  Shaad M Ahmad, Brian W Busser, Di Huang, Eliza...
# 684                              A M Boulet, M P Scott
#
# [90 rows x 6 columns]
