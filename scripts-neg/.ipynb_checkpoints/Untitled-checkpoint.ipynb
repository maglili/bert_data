# %% [markdown]
# # Extract negtive data
# Extract from new negtive set

# %%
import pandas as pd
import matplotlib.pyplot as plt

import random
random.seed(0)
import numpy as np
np.random.seed(0)

# %%
def check_year_distr(year_list: list) -> dict:
    """
    input: a list containing year.
        -e.g. year_list = [1998, 1998, 1999, 1999,...]
        
    output: a dictionary.
        -key: years
        -values: year count
    """
    year_set = {}
    for year in year_list:
        if year not in year_set:
            year_set[year] = 1
        else:
            year_set[year] += 1
    return year_set

# %% [markdown]
# ## Load data

# %% [markdown]
# ### positive data

# %%
# pos data
pos_df = pd.read_csv('../csv_data/output-pos-remove_no_abst.csv', squeeze=True, header=None, encoding='iso-8859-1', dtype=str)
pos_df = pos_df.fillna('')
pos_df
# Out:
#             0                                                  1  \
# 0    10028969  Frizzled regulation of Notch signalling polari...
# 1    10101114  Cis-regulatory elements of the mitotic regulat...
# 2    10198247  Identification of a novel cis-acting positive ...
# 3    10198632  twin of eyeless, a second Pax-6 gene of Drosop...
# 4    10207149  Direct regulatory interaction of the eyeless p...
# ..        ...                                                ...
# 894   9847251  Regulation of Pax6 expression is conserved bet...
# 895   9858707  Transcriptional control of Drosophila bicoid b...
# 896   9882489  Drosophila mef2 expression during mesoderm dev...
# 897   9892357  A LIM-homeodomain combinatorial code for motor...
# 898   9892673  Functional analysis of an eye specific enhance...
#
#                                                      2  \
# 0    The Drosophila eye, a paradigm for epithelial ...
# 1    Mitosis in most Drosophila cells is triggered ...
# 2    The Drosophila NK-1 homeobox gene belongs to t...
# 3    The Drosophila Pax-6 gene eyeless (ey) plays a...
# 4    The Pax-6 gene encodes a transcription factor ...
# ..                                                 ...
# 894  Pax6 plays a key role in visual system develop...
# 895  Concentration of maternal BICOID (BCD) establi...
# 896  The function of the Drosophila mef2 gene, a me...
# 897  Different classes of vertebrate motor neuron t...
# 898  The development of the Drosophila compound eye...
#
#                                  3     4  \
# 0                    10.1038/17395  1999
# 1                                   1999
# 2           10.1006/bbrc.1999.0501  1999
# 3    10.1016/s1097-2765(00)80457-8  1999
# 4                                   1999
# ..                             ...   ...
# 894                                 1999
# 895  10.1016/s0925-4773(98)00159-2  1998
# 896         10.1006/dbio.1998.9081  1998
# 897                  10.1038/16275  1999
# 898          10.1073/pnas.96.2.564  1999
#
#                                                      5
# 0                                 M T Cooper, S J Bray
# 1    D A Lehman, B Patterson, L A Johnston, T Balze...
# 2                             S J Kim, T Park, K K Lee
# 3    T Czerny, G Halder, U Kloter, A Souabni, W J G...
# 4    T Niimi, M Seimiya, U Kloter, S Flister, W J G...
# ..                                                 ...
# 894  P X Xu, X Zhang, S Heaney, A Yoon, A M Michels...
# 895                         C Ruez, F Payre, A Vincent
# 896                                   H T Nguyen, X Xu
# 897     S Thor, S G Andersson, A Tomlinson, J B Thomas
# 898                   B Hauck, W J Gehring, U Walldorf
#
# [899 rows x 6 columns]

# %%
pos_pmid = pos_df[0].tolist()

# pos year distribution
pos_year_list = pos_df[4].to_list()
pos_year_set = check_year_distr(pos_year_list)

# %%
pos_year_set
# Out:
# {'1999': 30,
#  '2000': 36,
#  '2001': 22,
#  '2002': 32,
#  '2003': 31,
#  '1992': 20,
#  '2004': 32,
#  '2005': 41,
#  '2006': 26,
#  '1987': 3,
#  '1991': 22,
#  '2007': 39,
#  '2008': 37,
#  '2009': 32,
#  '1990': 17,
#  '2010': 40,
#  '2011': 34,
#  '2012': 38,
#  '2013': 24,
#  '2014': 37,
#  '1986': 4,
#  '1989': 20,
#  '2015': 35,
#  '2016': 18,
#  '2017': 22,
#  '1988': 8,
#  '2018': 18,
#  '1985': 2,
#  '2019': 25,
#  '2020': 5,
#  '1995': 31,
#  '1994': 26,
#  '1993': 25,
#  '1996': 19,
#  '1997': 26,
#  '1998': 22}

# %% [markdown]
# ### negtive data

# %%
# neg data
neg_df = pd.read_csv('../csv_data/output_neg_all.csv', squeeze=True, header=None, encoding='iso-8859-1', dtype=str)
neg_df = neg_df.fillna('')
neg_df
# Out:
#                                                        0         1  \
# 0      The microbiota of Drosophila suzukii influence...  31763075
# 1      Evolution of a central neural circuit underlie...  29995860
# 2      Immunity in Drosophila melanogaster--from micr...  25421701
# 3      Carnivory in the larvae of Drosophila melanoga...  30341324
# 4            Can Drosophila melanogaster tell who's who?  30356241
# ...                                                  ...       ...
# 27162  Developmental stages of genome elimination res...   6790343
# 27163  Analysis of genetic variation affecting the re...   6781471
# 27164  Evidence that the repair deficient mei-9a fema...   6799290
# 27165     [Heterochromatin and chromosomal polymorphism]    109749
# 27166  Isolation and characterization of X-linked let...  24413794
#
#                                   2  \
# 0                10.7717/peerj.8097
# 1         10.1038/s41586-018-0322-9
# 2                   10.1038/nri3763
# 3        10.1038/s41598-018-33906-w
# 4      10.1371/journal.pone.0205043
# ...                             ...
# 27162
# 27163            10.1007/BF00484592
# 27164         10.1002/em.2860020211
# 27165
# 27166            10.1007/BF00281284
#
#                                                        3     4  \
# 0      Microorganisms play a central role in the biol...  2019
# 1      Courtship rituals serve to reinforce reproduct...  2018
# 2      Since the discovery of antimicrobial peptide r...  2014
# 3      Drosophila melanogaster is widely used as a mo...  2018
# 4      Drosophila melanogaster are known to live in a...  2018
# ...                                                  ...   ...
# 27162  T-007 is a Male Recombination (MR) second chro...  1981
# 27163  When AdhF/Adhs heterozygote homogenates are st...  1980
# 27164  From mating of Xc2/BsYy+ males treated or not ...  1980
# 27165  The structure and sizes of different short del...  1977
# 27166  Twenty-seven late larval or early pupal lethal...  1976
#
#                                                        5
# 0      Gabrielle M Solomon, Hiruni Dodangoda, Tylea M...
# 1      Laura F Seeholzer, Max Seppo, David L Stern, V...
# 2            Nicolas Buchon, Neal Silverman, Sara Cherry
# 3                                           Daxiang Yang
# 4      Jonathan Schneider, Nihal Murali, Graham W Tay...
# ...                                                  ...
# 27162                         K A Matthews, K A Matthews
# 27163                             A Grossman, A Grossman
# 27164  S Zimmering, A W Hartmann, S F Cooper, S Zimme...
# 27165  A A Prokof'eva-Bel'govskaia, A A Prokof'eva-Be...
# 27166  I Kiss, G Bencze, E Fekete, A Fodor, J Gausz, ...
#
# [27167 rows x 6 columns]

# %%
pmid_err = 0
abst_err = 0
remove_list = []

for i in range(len(neg_df)):
    pmid = neg_df.iloc[i][1]
    abst = neg_df.iloc[i][3]
    if pmid in pos_pmid:
        pmid_err += 1
        remove_list.append(i)
    if (abst == 'No abstract available') or (abst == ''):
        abst_err += 1
        remove_list.append(i)
        
print('remove samples:',pmid_err+abst_err)
print('pmid error:',pmid_err)
print('abst error:',abst_err)

neg_df = neg_df.drop(remove_list)
neg_df
# Out:
# remove samples: 3745
# pmid error: 175
# abst error: 3570
#                                                        0         1  \
# 0      The microbiota of Drosophila suzukii influence...  31763075
# 1      Evolution of a central neural circuit underlie...  29995860
# 2      Immunity in Drosophila melanogaster--from micr...  25421701
# 3      Carnivory in the larvae of Drosophila melanoga...  30341324
# 4            Can Drosophila melanogaster tell who's who?  30356241
# ...                                                  ...       ...
# 27162  Developmental stages of genome elimination res...   6790343
# 27163  Analysis of genetic variation affecting the re...   6781471
# 27164  Evidence that the repair deficient mei-9a fema...   6799290
# 27165     [Heterochromatin and chromosomal polymorphism]    109749
# 27166  Isolation and characterization of X-linked let...  24413794
#
#                                   2  \
# 0                10.7717/peerj.8097
# 1         10.1038/s41586-018-0322-9
# 2                   10.1038/nri3763
# 3        10.1038/s41598-018-33906-w
# 4      10.1371/journal.pone.0205043
# ...                             ...
# 27162
# 27163            10.1007/BF00484592
# 27164         10.1002/em.2860020211
# 27165
# 27166            10.1007/BF00281284
#
#                                                        3     4  \
# 0      Microorganisms play a central role in the biol...  2019
# 1      Courtship rituals serve to reinforce reproduct...  2018
# 2      Since the discovery of antimicrobial peptide r...  2014
# 3      Drosophila melanogaster is widely used as a mo...  2018
# 4      Drosophila melanogaster are known to live in a...  2018
# ...                                                  ...   ...
# 27162  T-007 is a Male Recombination (MR) second chro...  1981
# 27163  When AdhF/Adhs heterozygote homogenates are st...  1980
# 27164  From mating of Xc2/BsYy+ males treated or not ...  1980
# 27165  The structure and sizes of different short del...  1977
# 27166  Twenty-seven late larval or early pupal lethal...  1976
#
#                                                        5
# 0      Gabrielle M Solomon, Hiruni Dodangoda, Tylea M...
# 1      Laura F Seeholzer, Max Seppo, David L Stern, V...
# 2            Nicolas Buchon, Neal Silverman, Sara Cherry
# 3                                           Daxiang Yang
# 4      Jonathan Schneider, Nihal Murali, Graham W Tay...
# ...                                                  ...
# 27162                         K A Matthews, K A Matthews
# 27163                             A Grossman, A Grossman
# 27164  S Zimmering, A W Hartmann, S F Cooper, S Zimme...
# 27165  A A Prokof'eva-Bel'govskaia, A A Prokof'eva-Be...
# 27166  I Kiss, G Bencze, E Fekete, A Fodor, J Gausz, ...
#
# [23422 rows x 6 columns]

# %% [markdown]
# ## Processing data

# %% [markdown]
# Find Dataframe accroding to year

# %%
# save all data by its published year, balance data to fit pos data
all_set = dict()
for i in range(1985,2021): # 1985 ~ 2020 
    all_set[str(i)] = neg_df[neg_df[4]==str(i)]

# %%
# extract data
num_extract = 5
extract_pmid = []
extract_result = {} # save all dataset
random_seed = 0

for i in range(num_extract):
    
    extract_frames = []
    
    for year, appear_times in pos_year_set.items():         
        
        extract_data = all_set[year].sample(n=appear_times, random_state = random_seed)
        extr = len(extract_data)
        
        all_set[year] = all_set[year].drop(extract_data.index)
        aft = len(all_set[year])
        
        extract_frames.append(extract_data)
        
    result = pd.concat(extract_frames) #combine dataframes in frames
    #print(result)
    
    extract_result['dataset_'+str(i)] = result
    filename='neg_set'+str(i)+'.csv'
    #result.to_csv('../csv_data/neg_set/'+filename, header = False, index = False, encoding = 'utf-8')
    #print('='*60)

# %%
# examine year distribution
for dataframe in extract_result.values():
    years = dataframe[4].to_list()
    test_year_set = check_year_distr(years)
    print('Negtive year distribution == positive:', pos_year_set == test_year_set)
    print('='*50)
    
# examine redundant data
pmid_set = []
test = []
for dataset, dataframe in extract_result.items():
    pmid = dataframe[1].to_list()
    pmid_set.append(pmid)
    test.extend(pmid)
ori_ = len(test)
test = list(set(test))
aft_ = len(test)
print('ori_',ori_)
print('aft_',aft_)
    
redundant = 0
for i in range(num_extract):
    for j in range(i+1,num_extract):
        for k in pmid_set[i]:
            if k in pmid_set[j]:
                print('redundant')
                print(i)
                print(k)
                print(j)
                print('='*20)
                redunat += 1

if redundant == 0:
    print('No redundant!')
# Out:
# Negtive year distribution == positive: True
# ==================================================
# Negtive year distribution == positive: True
# ==================================================
# Negtive year distribution == positive: True
# ==================================================
# Negtive year distribution == positive: True
# ==================================================
# Negtive year distribution == positive: True
# ==================================================
# ori_ 4495
# aft_ 4495
# No redundant!
